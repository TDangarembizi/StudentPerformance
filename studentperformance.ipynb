# %%
url='/kaggle/input/students-performance-dataset/Student_performance_data _.csv'

# %%
import pandas as pd
data=pd.read_csv(url)

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
data.head()
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001   17       1          0                  2        19.833723
# 1       1002   18       0          0                  1        15.408756
# 2       1003   15       0          2                  3         4.210570
# 3       1004   17       1          0                  3        10.028829
# 4       1005   17       1          0                  2         4.672495
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1                2                0       0      1
# 1         0         0                1                0       0      0
# 2        26         0                2                0       0      0
# 3        14         0                3                1       0      0
# 4        17         1                3                0       0      0
#
#    Volunteering       GPA  GradeClass
# 0             0  2.929196         2.0
# ...

# %%
data.columns
# Out:
# Index(['StudentID', 'Age', 'Gender', 'Ethnicity', 'ParentalEducation',
#        'StudyTimeWeekly', 'Absences', 'Tutoring', 'ParentalSupport',
#        'Extracurricular', 'Sports', 'Music', 'Volunteering', 'GPA',
#        'GradeClass'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2392 entries, 0 to 2391
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   StudentID          2392 non-null   int64
#  1   Age                2392 non-null   int64
#  2   Gender             2392 non-null   int64
#  3   Ethnicity          2392 non-null   int64
#  4   ParentalEducation  2392 non-null   int64
#  5   StudyTimeWeekly    2392 non-null   float64
#  6   Absences           2392 non-null   int64
#  7   Tutoring           2392 non-null   int64
#  8   ParentalSupport    2392 non-null   int64
#  9   Extracurricular    2392 non-null   int64
#  10  Sports             2392 non-null   int64
#  11  Music              2392 non-null   int64
#  12  Volunteering       2392 non-null   int64
#  13  GPA                2392 non-null   float64
#  14  GradeClass         2392 non-null   float64
# dtypes: float64(3), int64(12)
# memory usage: 280.4 KB

# %%
missing=round((data.isnull().sum()/data.shape[0])*100,2)
print(missing)
# Out:
# StudentID            0.0
# Age                  0.0
# Gender               0.0
# Ethnicity            0.0
# ParentalEducation    0.0
# StudyTimeWeekly      0.0
# Absences             0.0
# Tutoring             0.0
# ParentalSupport      0.0
# Extracurricular      0.0
# Sports               0.0
# Music                0.0
# Volunteering         0.0
# GPA                  0.0
# GradeClass           0.0
# dtype: float64

# %%
data["StudentID"].unique()
# Out:
# array([1001, 1002, 1003, ..., 3390, 3391, 3392])

# %%
data["Age"].unique()
# Out:
# array([17, 18, 15, 16])

# %%
data["Gender"].unique()
# Out:
# array([1, 0])

# %%
data["Ethnicity"].unique()
# Out:
# array([0, 2, 1, 3])

# %%
data["ParentalEducation"].unique()
# Out:
# array([2, 1, 3, 4, 0])

# %%
data["StudyTimeWeekly"].unique()
# Out:
# array([19.83372281, 15.40875606,  4.21056977, ...,  6.80549964,
#        12.41665266, 17.81990749])

# %%
data["Absences"].unique()
# Out:
# array([ 7,  0, 26, 14, 17, 10, 22,  1, 11, 15, 21,  9, 16, 29,  2, 25, 20,
#         5,  8, 12, 27, 23,  3, 13,  6, 28,  4, 18, 19, 24])

# %%
data["Tutoring"].unique()
# Out:
# array([1, 0])

# %%
data["ParentalSupport"].unique()
# Out:
# array([2, 1, 3, 4, 0])

# %%
data["Extracurricular"].unique()
# Out:
# array([0, 1])

# %%
data["Sports"].unique()
# Out:
# array([0, 1])

# %%
data["Music"].unique()
# Out:
# array([1, 0])

# %%
data["Volunteering"].unique()
# Out:
# array([0, 1])

# %%
data["GPA"].unique()
# Out:
# array([2.92919559, 3.04291483, 0.11260225, ..., 1.14233288, 1.80329676,
#        2.14001388])

# %%
data["GradeClass"].unique()
# Out:
# array([2., 1., 4., 3., 0.])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.boxplot(x =data['Age'])
# Out:
# <Axes: xlabel='Age'>

# %%
sns.countplot(y='Gender', data=data)
ax = sns.countplot(y='Gender', data=data)

ax.set_yticklabels(['Male', 'Female'])
# Out:
# [Text(0, 0, 'Male'), Text(0, 1, 'Female')]

# %%
gender_counts = data["Gender"].value_counts()
labels = gender_counts.index.map({0: 'Male', 1: 'Female'})
plt.figure(figsize=(6, 6))
plt.pie(gender_counts, labels=labels, autopct='%1.1f%%', startangle=140)
plt.title('Gender')
plt.axis('equal')
plt.show()

# %%
eth_counts=data['Ethnicity'].value_counts()
labels=eth_counts.index.map({0: 'Caucasian',1: 'African American',2: 'Asian',3: 'Other'})
plt.figure(figsize=(6, 6))
plt.pie(eth_counts, labels=labels, autopct='%1.1f%%', startangle=140)
plt.title('Parental Education')
plt.axis('equal')
plt.show()

# %%
pEd_counts = data["ParentalEducation"].value_counts()
labels = pEd_counts.index.map({0: 'None',1: 'High School',2: 'Some College',3: 'Bachelors',4: 'Higher'})
plt.figure(figsize=(6, 6))
plt.pie(pEd_counts, labels=labels, autopct='%1.1f%%', startangle=140)
plt.title('Parental Education')
plt.axis('equal')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(data['StudyTimeWeekly'], bins=10, edgecolor='black')
plt.title('Distribution of Weekly Hours Studied')
plt.xlabel('Hours Studied')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(data['Absences'], bins=10, edgecolor='black')
plt.title('Distribution of Absences')
plt.xlabel('Number of Absences')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
tutor_counts = data["Tutoring"].value_counts()
labels = tutor_counts.index.map({0: 'No', 1: 'Yes'})
plt.figure(figsize=(6, 6))
plt.pie(tutor_counts, labels=labels, autopct='%1.1f%%', startangle=140)
plt.title('Tutoring')
plt.axis('equal')
plt.show()

# %%
pSup_counts = data["ParentalSupport"].value_counts()
labels = pSup_counts.index.map({0: 'None',1: 'Low',2: 'Moderate',3: 'High',4: 'Very High'})
plt.figure(figsize=(6, 6))
plt.pie(pSup_counts, labels=labels, autopct='%1.1f%%', startangle=140)
plt.title('Parental Support')
plt.axis('equal')
plt.show()

# %%
ex_counts = data["Extracurricular"].value_counts()
labels = ex_counts.index.map({0: 'No', 1: 'Yes'})
plt.figure(figsize=(6, 6))
plt.pie(ex_counts, labels=labels, autopct='%1.1f%%', startangle=140)
plt.title('Extracurricular')
plt.axis('equal')
plt.show()

# %%
sports_counts = data["Sports"].value_counts()
labels = sports_counts.index.map({0: 'No', 1: 'Yes'})
plt.figure(figsize=(6, 6))
plt.pie(sports_counts, labels=labels, autopct='%1.1f%%', startangle=140)
plt.title('Sports')
plt.axis('equal')
plt.show()

# %%
music_counts = data["Music"].value_counts()
labels = music_counts.index.map({0: 'No', 1: 'Yes'})
plt.figure(figsize=(6, 6))
plt.pie(music_counts, labels=labels, autopct='%1.1f%%', startangle=140)
plt.title('Music')
plt.axis('equal')
plt.show()

# %%
vol_counts = data["Volunteering"].value_counts()
labels = vol_counts.index.map({0: 'No', 1: 'Yes'})
plt.figure(figsize=(6, 6))
plt.pie(vol_counts, labels=labels, autopct='%1.1f%%', startangle=140)
plt.title('Volunteering')
plt.axis('equal')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(data['GPA'], bins=10, edgecolor='black')
plt.title('Distribution of GPA')
plt.xlabel('GPA')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
gClass_counts = data["GradeClass"].value_counts()
labels = gClass_counts.index.map({0: "'A' (GPA >= 3.5)",1: "'B' (3.0 <= GPA < 3.5)",2: "'C' (2.5 <= GPA < 3.0)",3: "'D' (2.0 <= GPA < 2.5)",4: "'F' (GPA < 2.0)"})
plt.figure(figsize=(6, 6))
plt.pie(gClass_counts, labels=labels, autopct='%1.1f%%', startangle=140)
plt.title('Grade Class')
plt.axis('equal')
plt.show()

# %%
class0=data[data['GradeClass']==0.0]
class1=data[data['GradeClass']==1.0]
class2=data[data['GradeClass']==2.0]
class3=data[data['GradeClass']==3.0]
class4=data[data['GradeClass']==4.0]

# %%
X=class0[['StudentID','Age','Gender','Ethnicity','ParentalEducation','StudyTimeWeekly','Absences','Tutoring','ParentalSupport','Extracurricular','Sports','Music','Volunteering']]
X.head()

# %%
Y=class0[['GradeClass']]
Y.head()

# %%
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer

model = KMeans()

visualizer = KElbowVisualizer(model, k=(2,10))

visualizer.fit(X)
visualizer.show()

# %%
from sklearn.cluster import KMeans
km = KMeans(n_clusters=4)

# %%
y_cluster = km.fit_predict(X)
print(y_cluster[0:5])
class0['ClusterLabel'] = y_cluster 
class0.head()

# %%
sns.countplot(data=class0, x="ClusterLabel", hue="Age")

# %%
labels = gender_counts.index.map({0: 'Male', 1: 'Female'})
sns.countplot(data=class0, x="ClusterLabel", hue="Gender")
plt.legend(title='Gender', labels=labels)

# %%
labels=eth_counts.index.map({0: 'Caucasian',1: 'African American',2: 'Asian',3: 'Other'})
sns.countplot(data=class0, x="ClusterLabel", hue="Ethnicity")
plt.legend(title='Ethnicity', labels=labels)

# %%
labels = pEd_counts.index.map({0: 'None',1: 'High School',2: 'Some College',3: 'Bachelors',4: 'Higher'})
sns.countplot(data=class0, x="ClusterLabel", hue="ParentalEducation")
plt.legend(title='Parental Education', labels=labels)

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=class0, x='StudyTimeWeekly', bins=10, hue='ClusterLabel', multiple='stack', edgecolor='black')
plt.title('Distribution of Weekly Study Time')
plt.xlabel('Study Time Weekly')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=class0, x='Absences', bins=10, hue='ClusterLabel', multiple='stack', edgecolor='black')
plt.title('Distribution of Absences')
plt.xlabel('Absences')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
labels = tutor_counts.index.map({0: 'No', 1: 'Yes'})
sns.countplot(data=class0, x="ClusterLabel", hue="Tutoring")
plt.legend(title='Tutoring', labels=labels)

# %%
labels = pSup_counts.index.map({0: 'None',1: 'Low',2: 'Moderate',3: 'High',4: 'Very High'})
sns.countplot(data=class0, x="ClusterLabel", hue="ParentalSupport")
plt.legend(title='Parental Support', labels=labels)

# %%
labels = ex_counts.index.map({0: 'No', 1: 'Yes'})
sns.countplot(data=class0, x="ClusterLabel", hue="Extracurricular")
plt.legend(title='Extracurricular', labels=labels)

# %%
labels = sports_counts.index.map({0: 'No', 1: 'Yes'})
sns.countplot(data=class0, x="ClusterLabel", hue="Sports")
plt.legend(title='Sports', labels=labels)

# %%
labels = music_counts.index.map({0: 'No', 1: 'Yes'})
sns.countplot(data=class0, x="ClusterLabel", hue="Music")
plt.legend(title='Music', labels=labels)

# %%
labels = vol_counts.index.map({0: 'No', 1: 'Yes'})
sns.countplot(data=class0, x="ClusterLabel", hue="Volunteering")
plt.legend(title='Volunteering', labels=labels)

# %%
X=class1[['StudentID','Age','Gender','Ethnicity','ParentalEducation','StudyTimeWeekly','Absences','Tutoring','ParentalSupport','Extracurricular','Sports','Music','Volunteering']
X.head()

# %%
Y=class1[['GradeClass']]
Y.head()

# %%
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer

model = KMeans()

visualizer = KElbowVisualizer(model, k=(2,10))

visualizer.fit(X)
visualizer.show()

# %%
X=class2[['StudentID','Age','Gender','Ethnicity','ParentalEducation','StudyTimeWeekly','Absences','Tutoring','ParentalSupport','Extracurricular','Sports','Music','Volunteering']]
X.head()

# %%
Y=class2[['GradeClass']]
Y.head()

# %%
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer

model = KMeans()

visualizer = KElbowVisualizer(model, k=(2,10))

visualizer.fit(X)
visualizer.show()

# %%
X=class3[['StudentID','Age','Gender','Ethnicity','ParentalEducation','StudyTimeWeekly','Absences','Tutoring','ParentalSupport','Extracurricular','Sports','Music','Volunteering']]
X.head()

# %%
Y=class3[['GradeClass']]
Y.head()

# %%
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer

model = KMeans()

visualizer = KElbowVisualizer(model, k=(2,10))

visualizer.fit(X)
visualizer.show()

# %%
X=class4[['StudentID','Age','Gender','Ethnicity','ParentalEducation','StudyTimeWeekly','Absences','Tutoring','ParentalSupport','Extracurricular','Sports','Music','Volunteering']]
X.head()

# %%
Y=class4[['GradeClass']]
Y.head()

# %%
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer

model = KMeans()

visualizer = KElbowVisualizer(model, k=(2,10))

visualizer.fit(X)
visualizer.show()

# %%
X=data[['StudentID','Age','Gender','Ethnicity','ParentalEducation','StudyTimeWeekly','Absences','Tutoring','ParentalSupport','Extracurricular','Sports','Music','Volunteering']]
X.head()

# %%
Y=data[['GradeClass']]
Y.head()
